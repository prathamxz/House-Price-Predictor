# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('punehouses.csv')
data
# Out:
#                   area_type   availability              location       size  \
# 0      Super built-up  Area         19-Dec           Alandi Road      2 BHK
# 1                Plot  Area  Ready To Move       Ambegaon Budruk  4 Bedroom
# 2            Built-up  Area  Ready To Move            Anandnagar      3 BHK
# 3      Super built-up  Area  Ready To Move                 Aundh      3 BHK
# 4      Super built-up  Area  Ready To Move            Aundh Road      2 BHK
# ...                     ...            ...                   ...        ...
# 13315        Built-up  Area  Ready To Move                Pashan  5 Bedroom
# 13316  Super built-up  Area  Ready To Move             Paud Road      4 BHK
# 13317        Built-up  Area  Ready To Move              Pirangut      2 BHK
# 13318  Super built-up  Area         18-Jun          Prabhat Road      4 BHK
# 13319  Super built-up  Area  Ready To Move  Pune Railway Station      1 BHK
#
#        society total_sqft  bath  balcony   price
# 0       Coomee       1056   2.0      1.0   39.07
# 1      Theanmp       2600   5.0      3.0  120.00
# 2          NaN       1440   2.0      3.0   62.00
# 3      Soiewre       1521   3.0      1.0   95.00
# 4          NaN       1200   2.0      1.0   51.00
# ...        ...        ...   ...      ...     ...
# 13315  ArsiaEx       3453   4.0      0.0  231.00
# 13316      NaN       3600   5.0      NaN  400.00
# 13317  Mahla T       1141   2.0      1.0   60.00
# 13318  SollyCl       4689   4.0      1.0  488.00
# 13319      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
data.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
data.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
data.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
data['location'].value_counts()
# Out:
# location
# Alandi Road            139
# Kalyani Nagar          139
# Mahatma Gandhi Road    139
# Lulla Nagar            139
# Laxmi Road             139
#                       ...
# Sadashiv Peth          138
# Raviwar Peth           138
# Rasta Peth             138
# Ghorpadi               138
# other                    1
# Name: count, Length: 97, dtype: int64

# %%
data['location']=data['location'].fillna('Warje')

# %%
data['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 14 BHK           1
# 13 BHK           1
# 12 Bedroom       1
# 27 BHK           1
# 43 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
data['size']=data['size'].fillna('2 BHK')

# %%
data.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size               0
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
print(data['bath'].mean())
print(data['bath'].median())
print(data['bath'].mode())
# Out:
# 2.6926096474673513
# 2.0
# 0    2.0
# Name: bath, dtype: float64

# %%
data['bath']=data['bath'].fillna(data['bath'].median())

# %%
data['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def convertRange(x):
    temp=x.split('-')
    if len(temp)==2:
        return (float(temp[0])+float(temp[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
data['total_sqft']=data['total_sqft'].apply(convertRange)

# %%
data['bhk']=data['size'].str.split().str.get(0).astype(int)

# %%
data[data.bhk>20]
# Out:
#                  area_type   availability       location        size society  \
# 1718  Super built-up  Area  Ready To Move  Uruli Devachi      27 BHK     NaN
# 4684            Plot  Area  Ready To Move  Salunke Vihar  43 Bedroom     NaN
#
#       total_sqft  bath  balcony  price  bhk
# 1718      8000.0  27.0      0.0  230.0   27
# 4684      2400.0  40.0      0.0  660.0   43

# %%
data['price_per_sqft']=data['price']*100000/data['total_sqft']

# %%
data.head()
# Out:
#               area_type   availability         location       size  society  \
# 0  Super built-up  Area         19-Dec      Alandi Road      2 BHK   Coomee
# 1            Plot  Area  Ready To Move  Ambegaon Budruk  4 Bedroom  Theanmp
# 2        Built-up  Area  Ready To Move       Anandnagar      3 BHK      NaN
# 3  Super built-up  Area  Ready To Move            Aundh      3 BHK  Soiewre
# 4  Super built-up  Area  Ready To Move       Aundh Road      2 BHK      NaN
#
#    total_sqft  bath  balcony   price  bhk  price_per_sqft
# 0      1056.0   2.0      1.0   39.07    2     3699.810606
# 1      2600.0   5.0      3.0  120.00    4     4615.384615
# 2      1440.0   2.0      3.0   62.00    3     4305.555556
# 3      1521.0   3.0      1.0   95.00    3     6245.890861
# 4      1200.0   2.0      1.0   51.00    2     4250.000000

# %%
data['location'].value_counts()
# Out:
# location
# Alandi Road            139
# Karve Nagar            139
# Mangalwar peth         139
# Mahatma Gandhi Road    139
# Lulla Nagar            139
#                       ...
# Sadashiv Peth          138
# Raviwar Peth           138
# Rasta Peth             138
# Ghorpadi               138
# other                    1
# Name: count, Length: 97, dtype: int64

# %%
data.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk  \
# count  13274.000000  13320.000000  12711.000000  13320.000000  13320.000000
# mean    1559.626694      2.688814      1.584376    112.565627      2.802778
# std     1238.405258      1.338754      0.817263    148.971674      1.294496
# min        1.000000      1.000000      0.000000      8.000000      1.000000
# 25%     1100.000000      2.000000      1.000000     50.000000      2.000000
# 50%     1276.000000      2.000000      2.000000     72.000000      3.000000
# 75%     1680.000000      3.000000      2.000000    120.000000      3.000000
# max    52272.000000     40.000000      3.000000   3600.000000     43.000000
#
#        price_per_sqft
# count    1.327400e+04
# mean     7.907501e+03
# std      1.064296e+05
# min      2.678298e+02
# 25%      4.266865e+03
# 50%      5.434306e+03
# 75%      7.311746e+03
# max      1.200000e+07

# %%
(data['total_sqft']/data['bhk']).describe()
# Out:
# count    13274.000000
# mean       575.074878
# std        388.205175
# min          0.250000
# 25%        473.333333
# 50%        552.500000
# 75%        625.000000
# max      26136.000000
# dtype: float64

# %%
data=data[((data['total_sqft']/data['bhk'])>=300)]
data.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk  \
# count  12530.000000  12530.000000  12014.000000  12530.000000  12530.000000
# mean    1594.564544      2.559537      1.587648    111.382401      2.650838
# std     1261.271296      1.077938      0.808842    152.077329      0.976678
# min      300.000000      1.000000      0.000000      8.440000      1.000000
# 25%     1116.000000      2.000000      1.000000     49.000000      2.000000
# 50%     1300.000000      2.000000      2.000000     70.000000      3.000000
# 75%     1700.000000      3.000000      2.000000    115.000000      3.000000
# max    52272.000000     16.000000      3.000000   3600.000000     16.000000
#
#        price_per_sqft
# count    12530.000000
# mean      6303.979357
# std       4162.237981
# min        267.829813
# 25%       4210.526316
# 50%       5294.117647
# 75%       6916.666667
# max     176470.588235

# %%
data.shape
# Out:
# (12530, 11)

# %%
data['location'] = data['location'].apply(lambda x: x.strip() if isinstance(x, str) else x)
location_count = data['location'].value_counts()
# Out:
# /var/folders/xv/xj4pndmx0jlbqqr2xcl3wy280000gn/T/ipykernel_6785/3325414000.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['location'] = data['location'].apply(lambda x: x.strip() if isinstance(x, str) else x)

# %%
location_count
# Out:
# location
# Yerawada           136
# Warje              135
# Kondhwa            135
# Sadashiv Peth      135
# Sasson Road        134
#                   ...
# Sahakar Nagar      126
# Ambegaon Budruk    125
# Salunke Vihar      124
# Pashan             124
# other                1
# Name: count, Length: 97, dtype: int64

# %%
location_count_less_10=location_count[location_count<=10]
location_count_less_10
# Out:
# location
# other    1
# Name: count, dtype: int64

# %%
data.price_per_sqft.describe()
# Out:
# count     12530.000000
# mean       6303.979357
# std        4162.237981
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
print(data.columns)
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price', 'bhk', 'price_per_sqft'],
#       dtype='object')

# %%
def remove_outliers_sqft(df):
    df_output=pd.DataFrame()
    for key,subdf in df.groupby('location'):
        m=np.mean(subdf.price_per_sqft)
        st=np.std(subdf.price_per_sqft)
        gen_df=subdf[(subdf.price_per_sqft>(m-st))&(subdf.price_per_sqft<=(m+st))]
        df_output=pd.concat([df_output,gen_df],ignore_index=True)
    return df_output
data=remove_outliers_sqft(data)
data.describe()
# Out:
#          total_sqft          bath       balcony         price           bhk  \
# count  10946.000000  10946.000000  10581.000000  10946.000000  10946.000000
# mean    1491.685042      2.456879      1.592572     83.924079      2.565777
# std      854.299518      0.961960      0.796885     66.182679      0.895302
# min      300.000000      1.000000      0.000000     10.000000      1.000000
# 25%     1105.000000      2.000000      1.000000     48.000000      2.000000
# 50%     1278.000000      2.000000      2.000000     65.000000      2.000000
# 75%     1629.750000      3.000000      2.000000     95.960000      3.000000
# max    30400.000000     16.000000      3.000000   2100.000000     16.000000
#
#        price_per_sqft
# count    10946.000000
# mean      5381.333751
# std       1606.407485
# min       1379.310345
# 25%       4186.046512
# 50%       5107.943007
# 75%       6333.333333
# max      17548.524329

# %%
def bhk_outlier_remover(df):
    exclude_indices=np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats={}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk]={
                'mean':np.mean(bhk_df.price_per_sqft),
                'std':np.std(bhk_df.price_per_sqft),
                'count':bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats=bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices=np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices, axis='index')

# %%
data=bhk_outlier_remover(data)

# %%
data.shape
# Out:
# (7466, 11)

# %%
data
# Out:
#                   area_type   availability     location       size  society  \
# 0      Super built-up  Area         19-Dec  Alandi Road      2 BHK   Coomee
# 1                Plot  Area  Ready To Move  Alandi Road  4 Bedroom  Goardth
# 2      Super built-up  Area  Ready To Move  Alandi Road      2 BHK  Bhinglv
# 3      Super built-up  Area  Ready To Move  Alandi Road      2 BHK  Aahts H
# 4      Super built-up  Area  Ready To Move  Alandi Road      3 BHK      NaN
# ...                     ...            ...          ...        ...      ...
# 10934  Super built-up  Area  Ready To Move     Yerawada      4 BHK  Prtanha
# 10937        Built-up  Area  Ready To Move     Yerawada  6 Bedroom      NaN
# 10940        Built-up  Area         18-Mar     Yerawada  5 Bedroom  Toainnt
# 10941  Super built-up  Area  Ready To Move     Yerawada      2 BHK  Jaw 2 L
# 10945  Super built-up  Area         18-Apr     Yerawada      2 BHK      NaN
#
#        total_sqft  bath  balcony   price  bhk  price_per_sqft
# 0          1056.0   2.0      1.0   39.07    2     3699.810606
# 1          2894.0   4.0      1.0  245.00    4     8465.791292
# 2          1084.0   2.0      2.0   50.00    2     4612.546125
# 3          1230.0   2.0      2.0   80.00    2     6504.065041
# 4          1750.0   3.0      2.0  130.00    3     7428.571429
# ...           ...   ...      ...     ...  ...             ...
# 10934      3122.0   6.0      2.0  250.00    4     8007.687380
# 10937      3500.0   6.0      NaN  115.00    6     3285.714286
# 10940      3210.0   2.0      NaN  353.00    5    10996.884735
# 10941      1050.0   2.0      2.0   54.00    2     5142.857143
# 10945      1132.0   2.0      1.0   70.00    2     6183.745583
#
# [7466 rows x 11 columns]

# %%
data.drop(columns=['area_type','availability','size','society','balcony','price_per_sqft'],inplace=True)

# %%
data.head()
# Out:
#       location  total_sqft  bath   price  bhk
# 0  Alandi Road      1056.0   2.0   39.07    2
# 1  Alandi Road      2894.0   4.0  245.00    4
# 2  Alandi Road      1084.0   2.0   50.00    2
# 3  Alandi Road      1230.0   2.0   80.00    2
# 4  Alandi Road      1750.0   3.0  130.00    3

# %%
data.to_csv('Cleaned_data.csv')

# %%
x=data.drop(columns=['price'])
y=data['price']

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
x_train, x_test, y_train, y_test=tts(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (5972, 4)
# (1494, 4)

# %%
column_trans=make_column_transformer((OneHotEncoder(sparse_output=False),['location']),remainder='passthrough')

# %%
scaler=StandardScaler()

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8874648858989062

# %%
lasso=Lasso()

# %%
pipe=make_pipeline(column_trans,scaler,lasso)

# %%
pipe.fit(x_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('lasso', Lasso())])

# %%
y_pred_lasso=pipe.predict(x_test)
r2_score(y_test,y_pred_lasso)
# Out:
# 0.8838266953683205

# %%
ridge=Ridge()

# %%
pipe=make_pipeline(column_trans,scaler,ridge)

# %%
pipe.fit(x_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/compose/_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['location'])])),
#                 ('standardscaler', StandardScaler()), ('ridge', Ridge())])

# %%
y_pred_ridge=pipe.predict(x_test)
r2_score(y_test,y_pred_ridge)
# Out:
# 0.8875295688276894

# %%
print('No Regularization: ',r2_score(y_test,y_pred))
print('Lasso: ',r2_score(y_test,y_pred_lasso))
print('Ridge: ',r2_score(y_test,y_pred_ridge))
# Out:
# No Regularization:  0.8874648858989062
# Lasso:  0.8838266953683205
# Ridge:  0.8875295688276894

# %%
import pickle

# %%
pickle.dump(pipe, open('RidgeModel.pkl','wb'))
